# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaStanly/internship/blob/main/day3%264.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data={
    "Name" : ["Alice","Bob","Charlie","David","Eve"],
    "Age" : [25,None,30,None,40],
    "Salary" : [5000,6000,None,8000,None],
    "City" : ["New York",None,"San Francisco","Los Angeles","Chicago"],
}
df=pd.DataFrame(data)
df
# Out:
#       Name   Age  Salary           City
# 0    Alice  25.0  5000.0       New York
# 1      Bob   NaN  6000.0           None
# 2  Charlie  30.0     NaN  San Francisco
# 3    David   NaN  8000.0    Los Angeles
# 4      Eve  40.0     NaN        Chicago

# %%
df.isna().sum()
# Out:
# Name      0
# Age       2
# Salary    2
# City      1
# dtype: int64

# %%
df.fillna("Unknown")
# Out:
#       Name      Age   Salary           City
# 0    Alice     25.0   5000.0       New York
# 1      Bob  Unknown   6000.0        Unknown
# 2  Charlie     30.0  Unknown  San Francisco
# 3    David  Unknown   8000.0    Los Angeles
# 4      Eve     40.0  Unknown        Chicago

# %%
df.ffill()
# Out:
#       Name   Age  Salary           City
# 0    Alice  25.0  5000.0       New York
# 1      Bob  25.0  6000.0       New York
# 2  Charlie  30.0  6000.0  San Francisco
# 3    David  30.0  8000.0    Los Angeles
# 4      Eve  40.0  8000.0        Chicago

# %%
df.bfill()
# Out:
#       Name   Age  Salary           City
# 0    Alice  25.0  5000.0       New York
# 1      Bob  30.0  6000.0  San Francisco
# 2  Charlie  30.0  8000.0  San Francisco
# 3    David  40.0  8000.0    Los Angeles
# 4      Eve  40.0     NaN        Chicago

# %%
df.fillna({'Age' : df['Age'].mean(),
           'Salary' : df['Salary'].median()})
# Out:
#       Name        Age  Salary           City
# 0    Alice  25.000000  5000.0       New York
# 1      Bob  31.666667  6000.0           None
# 2  Charlie  30.000000  6000.0  San Francisco
# 3    David  31.666667  8000.0    Los Angeles
# 4      Eve  40.000000  6000.0        Chicago

# %%
df.dropna(how="any")
# Out:
#     Name   Age  Salary      City
# 0  Alice  25.0  5000.0  New York

# %%
df.dropna(how="all")
# Out:
#       Name   Age  Salary           City
# 0    Alice  25.0  5000.0       New York
# 1      Bob   NaN  6000.0           None
# 2  Charlie  30.0     NaN  San Francisco
# 3    David   NaN  8000.0    Los Angeles
# 4      Eve  40.0     NaN        Chicago

# %%
df.dropna(axis=1)
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David
# 4      Eve

# %%
import seaborn as sns
data = sns.load_dataset('titanic')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data=data, x="age", kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
data.drop(columns=["class","embark_town","alive","deck"],inplace=True)
data["age"]=data["age"].fillna(data["age"].mean())
data['embarked'] = data['embarked'].fillna(data['embarked'].mode()[0])

# %%
data['embarked'].mode()[0]
# Out:
# 'S'

# %%
data.isna().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# who           0
# adult_male    0
# alone         0
# dtype: int64

# %%
data['family_size'] = data['sibsp'] + data['parch'] + 1
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  71.2833        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    adult_male  alone  family_size
# 0        True  False            2
# 1       False  False            2
# 2       False   True            1
# 3       False  False            2
# 4        True   True            1

# %%
sns.boxplot((data['age'],data['fare']))
# Out:
# <Axes: >

# %%
Q1 = data['age'].quantile(0.25)
Q3 = data['age'].quantile(0.75)
IQR = Q3-Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR
print(Q1,Q3,IQR,lower_bound,upper_bound)
data['age'] = data['age'].clip(lower_bound,upper_bound)
# Out:
# 22.0 35.0 13.0 2.5 54.5

# %%
Q1 = data['fare'].quantile(0.25)
Q3 = data['fare'].quantile(0.75)
IQR = Q3-Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 +1.5*IQR
print(Q1,Q3,IQR,lower_bound,upper_bound)
data['fare'] = data['fare'].clip(lower_bound,upper_bound)
# Out:
# 7.9104 31.0 23.0896 -26.724 65.6344

# %%
sns.boxplot((data['age'],data['fare']))
# Out:
# <Axes: >

# %%
data['adult_male'] = data['adult_male'].astype(int)
data['alone'] = data['alone'].map({True:1,False:0})
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    male  22.0      1      0   7.2500        S    man
# 1         1       1  female  38.0      1      0  65.6344        C  woman
# 2         1       3  female  26.0      0      0   7.9250        S  woman
# 3         1       1  female  35.0      1      0  53.1000        S  woman
# 4         0       3    male  35.0      0      0   8.0500        S    man
#
#    adult_male  alone  family_size
# 0           1      0            2
# 1           0      0            2
# 2           0      1            1
# 3           0      0            2
# 4           1      1            1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['sex'] = le.fit_transform(data['sex'])
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked    who  \
# 0         0       3    1  22.0      1      0   7.2500        S    man
# 1         1       1    0  38.0      1      0  65.6344        C  woman
# 2         1       3    0  26.0      0      0   7.9250        S  woman
# 3         1       1    0  35.0      1      0  53.1000        S  woman
# 4         0       3    1  35.0      0      0   8.0500        S    man
#
#    adult_male  alone  family_size
# 0           1      0            2
# 1           0      0            2
# 2           0      1            1
# 3           0      0            2
# 4           1      1            1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['embarked'] = le.fit_transform(data['embarked'])
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked    who  \
# 0         0       3    1  22.0      1      0   7.2500         2    man
# 1         1       1    0  38.0      1      0  65.6344         0  woman
# 2         1       3    0  26.0      0      0   7.9250         2  woman
# 3         1       1    0  35.0      1      0  53.1000         2  woman
# 4         0       3    1  35.0      0      0   8.0500         2    man
#
#    adult_male  alone  family_size
# 0           1      0            2
# 1           0      0            2
# 2           0      1            1
# 3           0      0            2
# 4           1      1            1

# %%
import pandas as pd
data2 = pd.get_dummies(data,columns=['who'],dtype=int,drop_first=True)
data2
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare  embarked  \
# 0           0       3    1  22.000000      1      0   7.2500         2
# 1           1       1    0  38.000000      1      0  65.6344         0
# 2           1       3    0  26.000000      0      0   7.9250         2
# 3           1       1    0  35.000000      1      0  53.1000         2
# 4           0       3    1  35.000000      0      0   8.0500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         2
# 887         1       1    0  19.000000      0      0  30.0000         2
# 888         0       3    0  29.699118      1      2  23.4500         2
# 889         1       1    1  26.000000      0      0  30.0000         0
# 890         0       3    1  32.000000      0      0   7.7500         1
#
#      adult_male  alone  family_size  who_man  who_woman
# 0             1      0            2        1          0
# ...

# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
corr_matrix = data[num_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='crest')
plt.show()

# %%
import matplotlib.pyplot as plt
corr_matrix = df_scaled[num_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='crest')
plt.show()

# %%
num_cols = ['age','fare']
from sklearn.preprocessing import StandardScaler,MinMaxScaler
sd=StandardScaler()
df_scaled = data2.copy()
df_scaled[num_cols] = sd.fit_transform(data2[num_cols])
df_scaled.head()
# Out:
#    survived  pclass  sex       age  sibsp  parch      fare  embarked  \
# 0         0       3    1 -0.611917      1      0 -0.820552         2
# 1         1       1    0  0.715304      1      0  2.031623         0
# 2         1       3    0 -0.280111      0      0 -0.787578         2
# 3         1       1    0  0.466450      1      0  1.419297         2
# 4         0       3    1  0.466450      0      0 -0.781471         2
#
#    adult_male  alone  family_size  who_man  who_woman
# 0           1      0            2        1          0
# 1           0      0            2        0          1
# 2           0      1            1        0          1
# 3           0      0            2        0          1
# 4           1      1            1        1          0

# %%
df=MinMaxScaler()
df_scaled1 = data2.copy()
df_scaled[num_cols] = sd.fit_transform(data2[num_cols])
df_scaled.head()
# Out:
#    survived  pclass  sex       age  sibsp  parch      fare  embarked  \
# 0         0       3    1 -0.611917      1      0 -0.820552         2
# 1         1       1    0  0.715304      1      0  2.031623         0
# 2         1       3    0 -0.280111      0      0 -0.787578         2
# 3         1       1    0  0.466450      1      0  1.419297         2
# 4         0       3    1  0.466450      0      0 -0.781471         2
#
#    adult_male  alone  family_size  who_man  who_woman
# 0           1      0            2        1          0
# 1           0      0            2        0          1
# 2           0      1            1        0          1
# 3           0      0            2        0          1
# 4           1      1            1        1          0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='crest')
plt.show()

# %%
df_scaled.describe()
# Out:
#          survived      pclass         sex           age       sibsp  \
# count  891.000000  891.000000  891.000000  8.910000e+02  891.000000
# mean     0.383838    2.308642    0.647587  7.974666e-18    0.523008
# std      0.486592    0.836071    0.477990  1.000562e+00    1.102743
# min      0.000000    1.000000    0.000000 -2.229467e+00    0.000000
# 25%      0.000000    2.000000    0.000000 -6.119166e-01    0.000000
# 50%      0.000000    3.000000    1.000000  2.673527e-02    0.000000
# 75%      1.000000    3.000000    1.000000  4.664504e-01    1.000000
# max      1.000000    3.000000    1.000000  2.084001e+00    8.000000
#
#             parch          fare    embarked  adult_male       alone  \
# count  891.000000  8.910000e+02  891.000000  891.000000  891.000000
# mean     0.381594  9.968332e-17    1.536476    0.602694    0.602694
# std      0.806057  1.000562e+00    0.791503    0.489615    0.489615
# min      0.000000 -1.174727e+00    0.000000    0.000000    0.000000
# ...

# %%
from sklearn.model_selection import train_test_split
y= data2['survived']
x=data2.drop(columns=['survived'])

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (712, 12) (179, 12) (712,) (179,)

# %%
x_test.index

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
lr = LogisticRegression()
lr_model = lr.fit(x_train,y_train)
lr_pred  = lr_model.predict(x_test)

print(accuracy_score(y_test,lr_pred))
print(confusion_matrix(y_test,lr_pred))

print(classification_report(y_test,lr_pred))
# Out:
# 0.8100558659217877
# [[91 14]
#  [20 54]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84       105
#            1       0.79      0.73      0.76        74
#
#     accuracy                           0.81       179
#    macro avg       0.81      0.80      0.80       179
# weighted avg       0.81      0.81      0.81       179
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_test.value_counts()
# Out:
# survived
# 0    105
# 1     74
# Name: count, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
metric_k = []
for k in range(1,20):
  knn = KNeighborsClassifier(n_neighbors=k)
  knn_model = knn.fit(x_train,y_train)
  knn_pred = knn_model.predict(x_test)
  metric_k.append(accuracy_score(y_test,knn_pred))
metric_k
# Out:
# [0.7374301675977654,
#  0.6983240223463687,
#  0.7374301675977654,
#  0.7541899441340782,
#  0.7374301675977654,
#  0.7541899441340782,
#  0.7374301675977654,
#  0.7541899441340782,
#  0.7597765363128491,
#  0.7486033519553073,
#  0.7541899441340782,
#  0.7430167597765364,
#  0.7486033519553073,
#  0.7262569832402235,
#  0.7486033519553073,
#  0.7318435754189944,
#  0.7318435754189944,
#  0.7094972067039106,
#  0.7094972067039106]

# %%
import matplotlib.pyplot as plt

# Assuming metric_k contains accuracy scores from k = 1 to 19
plt.figure(figsize=(8,5))
plt.plot(range(1, 20), metric_k, marker='o', linestyle='-', color='blue')

plt.title('KNN Accuracy for Different Values of K')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Accuracy')
plt.xticks(range(1, 20))  # Ensure all K values are shown on the x-axis
plt.grid(True)
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn_model = knn.fit(x_train,y_train)
knn_pred = knn_model.predict(x_test)
print(accuracy_score(y_test,knn_pred))
print(confusion_matrix(y_test,knn_pred))
print(classification_report(y_test,knn_pred))
# Out:
# 0.7597765363128491
# [[87 18]
#  [25 49]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       105
#            1       0.73      0.66      0.70        74
#
#     accuracy                           0.76       179
#    macro avg       0.75      0.75      0.75       179
# weighted avg       0.76      0.76      0.76       179

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
dt_model = knn.fit(x_train,y_train)
dt_pred = dt_model.predict(x_test)

print(accuracy_score(y_test,dt_pred))
print(confusion_matrix(y_test,dt_pred))
print(classification_report(y_test,dt_pred))
# Out:
# 0.7597765363128491
# [[87 18]
#  [25 49]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       105
#            1       0.73      0.66      0.70        74
#
#     accuracy                           0.76       179
#    macro avg       0.75      0.75      0.75       179
# weighted avg       0.76      0.76      0.76       179

# %%
dt_model = DecisionTreeClassifier(criterion='gini',max_depth=3,min_samples_split=10,min_samples_leaf=5,random_state=3)
dt_model = knn.fit(x_train,y_train)
dt_pred = dt_model.predict(x_test)

print(accuracy_score(y_test,dt_pred))
print(confusion_matrix(y_test,dt_pred))
print(classification_report(y_test,dt_pred))
# Out:
# 0.7597765363128491
# [[87 18]
#  [25 49]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       105
#            1       0.73      0.66      0.70        74
#
#     accuracy                           0.76       179
#    macro avg       0.75      0.75      0.75       179
# weighted avg       0.76      0.76      0.76       179

# %%
dt_model = DecisionTreeClassifier(criterion='gini',max_depth=3,min_samples_split=10,min_samples_leaf=5,random_state=3)
dt_model.fit(x_train,y_train)
dt_pred = dt_model.predict(x_test)

print(accuracy_score(y_test,dt_pred))
print(confusion_matrix(y_test,dt_pred))
print(classification_report(y_test,dt_pred))
# Out:
# 0.8100558659217877
# [[92 13]
#  [21 53]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       105
#            1       0.80      0.72      0.76        74
#
#     accuracy                           0.81       179
#    macro avg       0.81      0.80      0.80       179
# weighted avg       0.81      0.81      0.81       179

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(x_train,y_train)
rf_pred = rf_model.predict(x_test)
print(accuracy_score(y_test,dt_pred))
print(confusion_matrix(y_test,dt_pred))
print(classification_report(y_test,dt_pred))
# Out:
# 0.8100558659217877
# [[92 13]
#  [21 53]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       105
#            1       0.80      0.72      0.76        74
#
#     accuracy                           0.81       179
#    macro avg       0.81      0.80      0.80       179
# weighted avg       0.81      0.81      0.81       179

# %%
rf_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf_model_tuned=RandomForestClassifier(n_estimators=100,max_depth=5,min_samples_split=10,min_samples_leaf=5,random_state=42,max_features="sqrt")
rf_model_tuned.fit(x_train,y_train)
rf_pred_tuned=rf_model_tuned.predict(x_test)
print(accuracy_score(y_test,rf_pred_tuned))
print(confusion_matrix(y_test,rf_pred_tuned))
print(classification_report(y_test,rf_pred_tuned))
rf_model_tuned.get_params()
# Out:
# 0.8100558659217877
# [[92 13]
#  [21 53]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84       105
#            1       0.80      0.72      0.76        74
#
#     accuracy                           0.81       179
#    macro avg       0.81      0.80      0.80       179
# weighted avg       0.81      0.81      0.81       179
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 5,
#  'min_samples_split': 10,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}
